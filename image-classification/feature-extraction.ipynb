# %%
import pandas as pd
import cv2
import numpy as np
import os
import time
import matplotlib.pyplot as plt

from tqdm import tqdm
from rembg import remove
from PIL import Image
from scipy.stats import skew

# %%
image_path = "data/masked-train-set/"
print(os.listdir(image_path))
# Out:
# ['ADONIS', 'AFRICAN GIANT SWALLOWTAIL', 'AMERICAN SNOOT', 'AN 88', 'APPOLLO', 'ATALA', 'BANDED ORANGE HELICONIAN', 'BANDED PEACOCK', 'BECKERS WHITE', 'BLACK HAIRSTREAK', 'BLUE MORPHO', 'BLUE SPOTTED CROW', 'BROWN SIPROETA', 'CABBAGE WHITE', 'CAIRNS BIRDWING', 'CHECQUERED SKIPPER', 'CHESTNUT', 'CLEOPATRA', 'CLODIUS PARNASSIAN', 'CLOUDED SULPHUR', 'COMMON BANDED AWL', 'COMMON WOOD-NYMPH', 'COPPER TAIL', 'CRECENT', 'CRIMSON PATCH', 'DANAID EGGFLY', 'EASTERN COMA', 'EASTERN DAPPLE WHITE', 'EASTERN PINE ELFIN', 'ELBOWED PIERROT', 'GOLD BANDED', 'GREAT EGGFLY', 'GREAT JAY', 'GREEN CELLED CATTLEHEART', 'GREY HAIRSTREAK', 'INDRA SWALLOW', 'IPHICLUS SISTER', 'JULIA', 'LARGE MARBLE', 'MALACHITE', 'MANGROVE SKIPPER', 'MESTRA', 'METALMARK', 'MILBERTS TORTOISESHELL', 'MONARCH', 'MOURNING CLOAK', 'ORANGE OAKLEAF', 'ORANGE TIP', 'ORCHARD SWALLOW', 'PAINTED LADY', 'PAPER KITE', 'PEACOCK', 'PINE WHITE', 'PIPEVINE SWALLOW', 'POPINJAY', 'PURPLE HAIRSTREAK', 'PURPLISH COPPER', 'QUESTION MARK', 'RED ADMIRAL', 'RED CRACKER', 'RED POSTMAN', 'RED SPOTTED PURPLE', 'SCARCE SWALLOW', 'SILVER SPOT SKIPPER', 'SLEEPY ORANGE', 'SOOTYWING', 'SOUTHERN DOGFACE', 'STRAITED QUEEN', 'TROPICAL LEAFWING', 'TWO BARRED FLASHER', 'ULYSES', 'VICEROY', 'WOOD SATYR', 'YELLOW SWALLOW TAIL', 'ZEBRA LONG WING']

# %%
adonis = image_path + "ADONIS/"
clouded_sulphur = image_path + "CLOUDED SULPHUR/"
scarce_swallow = image_path + "SCARCE SWALLOW/"

print(f"Adonis: {len(os.listdir(adonis))}")
print(f"Clouded Sulphur: {len(os.listdir(clouded_sulphur))}")
print(f"Scarce Swallow: {len(os.listdir(scarce_swallow))}")

output_path = "data/no-bg/"
if not os.path.exists(output_path):
    os.makedirs(output_path)
# Out:
# Adonis: 88
# Clouded Sulphur: 92
# Scarce Swallow: 97

# %%
def remove_bg_and_resize(input_dir, output_dir, size=(128, 128)):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for filename in os.listdir(input_dir):
        if filename.lower().endswith((".jpg", ".jpeg", ".png")):
            input_file = os.path.join(input_dir, filename)
            output_file = os.path.join(output_dir, os.path.splitext(filename)[0] + ".png")

            start_time = time.time()

            with open(input_file, "rb") as f:
                input_image = Image.open(f).convert("RGBA")

            output_image = remove(input_image)
            output_image = output_image.resize(size, Image.LANCZOS)
            output_image.save(output_file)

            print(f"Processed: {filename}, elapsed time: {time.time() - start_time:.2f} seconds")

remove_bg_and_resize(adonis, os.path.join(output_path, "adonis"))
remove_bg_and_resize(clouded_sulphur, os.path.join(output_path, "clouded_sulphur"))
remove_bg_and_resize(scarce_swallow, os.path.join(output_path, "scarce_swallow"))
# Out:
# Processed: Image_1087.jpg, elapsed time: 1.22 seconds
# Processed: Image_1131.jpg, elapsed time: 1.11 seconds
# Processed: Image_1211.jpg, elapsed time: 1.10 seconds
# Processed: Image_1565.jpg, elapsed time: 1.06 seconds
# Processed: Image_1712.jpg, elapsed time: 1.03 seconds
# Processed: Image_1772.jpg, elapsed time: 1.05 seconds
# Processed: Image_1849.jpg, elapsed time: 1.05 seconds
# Processed: Image_1858.jpg, elapsed time: 1.06 seconds
# Processed: Image_1907.jpg, elapsed time: 1.04 seconds
# Processed: Image_1927.jpg, elapsed time: 1.06 seconds
# Processed: Image_1937.jpg, elapsed time: 1.03 seconds
# Processed: Image_2.jpg, elapsed time: 1.00 seconds
# Processed: Image_2101.jpg, elapsed time: 1.02 seconds
# Processed: Image_2132.jpg, elapsed time: 1.02 seconds
# Processed: Image_2203.jpg, elapsed time: 1.00 seconds
# Processed: Image_2255.jpg, elapsed time: 1.01 seconds
# Processed: Image_2275.jpg, elapsed time: 0.99 seconds
# Processed: Image_2360.jpg, elapsed time: 0.99 seconds
# Processed: Image_2401.jpg, elapsed time: 1.03 seconds
# Processed: Image_2409.jpg, elapsed time: 1.00 seconds
# Processed: Image_2488.jpg, elapsed time: 0.98 seconds
# Processed: Image_2516.jpg, elapsed time: 0.98 seconds
# Processed: Image_2520.jpg, elapsed time: 1.01 seconds
# Processed: Image_2584.jpg, elapsed time: 0.99 seconds
# Processed: Image_2655.jpg, elapsed time: 0.99 seconds
# Processed: Image_2689.jpg, elapsed time: 0.99 seconds
# Processed: Image_2694.jpg, elapsed time: 1.01 seconds
# Processed: Image_2722.jpg, elapsed time: 1.03 seconds
# Processed: Image_280.jpg, elapsed time: 0.99 seconds
# Processed: Image_2814.jpg, elapsed time: 0.99 seconds
# Processed: Image_2959.jpg, elapsed time: 1.01 seconds
# Processed: Image_2960.jpg, elapsed time: 1.02 seconds
# Processed: Image_3009.jpg, elapsed time: 1.00 seconds
# Processed: Image_3036.jpg, elapsed time: 0.99 seconds
# Processed: Image_3108.jpg, elapsed time: 1.00 seconds
# Processed: Image_3141.jpg, elapsed time: 0.99 seconds
# Processed: Image_3200.jpg, elapsed time: 0.99 seconds
# Processed: Image_3228.jpg, elapsed time: 1.00 seconds
# Processed: Image_3276.jpg, elapsed time: 1.03 seconds
# Processed: Image_330.jpg, elapsed time: 0.99 seconds
# Processed: Image_3303.jpg, elapsed time: 1.00 seconds
# Processed: Image_348.jpg, elapsed time: 1.00 seconds
# Processed: Image_3553.jpg, elapsed time: 0.98 seconds
# Processed: Image_3559.jpg, elapsed time: 0.99 seconds
# Processed: Image_3621.jpg, elapsed time: 1.03 seconds
# Processed: Image_3660.jpg, elapsed time: 1.02 seconds
# Processed: Image_3740.jpg, elapsed time: 1.00 seconds
# Processed: Image_3784.jpg, elapsed time: 1.00 seconds
# Processed: Image_3809.jpg, elapsed time: 1.03 seconds
# Processed: Image_3829.jpg, elapsed time: 1.03 seconds
# Processed: Image_4009.jpg, elapsed time: 1.02 seconds
# Processed: Image_4117.jpg, elapsed time: 1.00 seconds
# Processed: Image_4123.jpg, elapsed time: 0.97 seconds
# Processed: Image_4126.jpg, elapsed time: 1.00 seconds
# Processed: Image_4209.jpg, elapsed time: 1.00 seconds
# Processed: Image_4247.jpg, elapsed time: 1.00 seconds
# Processed: Image_4293.jpg, elapsed time: 0.99 seconds
# Processed: Image_4339.jpg, elapsed time: 1.01 seconds
# Processed: Image_4444.jpg, elapsed time: 1.01 seconds
# Processed: Image_452.jpg, elapsed time: 0.98 seconds
# Processed: Image_4531.jpg, elapsed time: 1.01 seconds
# Processed: Image_4569.jpg, elapsed time: 1.01 seconds
# Processed: Image_461.jpg, elapsed time: 1.01 seconds
# Processed: Image_4643.jpg, elapsed time: 0.99 seconds
# Processed: Image_4769.jpg, elapsed time: 1.01 seconds
# Processed: Image_4790.jpg, elapsed time: 0.97 seconds
# Processed: Image_4857.jpg, elapsed time: 1.02 seconds
# Processed: Image_4932.jpg, elapsed time: 1.01 seconds
# Processed: Image_5102.jpg, elapsed time: 1.01 seconds
# Processed: Image_5394.jpg, elapsed time: 1.00 seconds
# Processed: Image_5542.jpg, elapsed time: 1.04 seconds
# Processed: Image_555.jpg, elapsed time: 1.02 seconds
# Processed: Image_5659.jpg, elapsed time: 1.08 seconds
# Processed: Image_5924.jpg, elapsed time: 1.05 seconds
# Processed: Image_5961.jpg, elapsed time: 1.02 seconds
# Processed: Image_6012.jpg, elapsed time: 1.05 seconds
# Processed: Image_6094.jpg, elapsed time: 1.05 seconds
# Processed: Image_6194.jpg, elapsed time: 1.08 seconds
# Processed: Image_6198.jpg, elapsed time: 1.03 seconds
# Processed: Image_624.jpg, elapsed time: 1.02 seconds
# Processed: Image_666.jpg, elapsed time: 1.03 seconds
# Processed: Image_774.jpg, elapsed time: 1.00 seconds
# Processed: Image_79.jpg, elapsed time: 1.03 seconds
# Processed: Image_796.jpg, elapsed time: 1.01 seconds
# Processed: Image_848.jpg, elapsed time: 1.01 seconds
# Processed: Image_901.jpg, elapsed time: 1.08 seconds
# Processed: Image_917.jpg, elapsed time: 1.09 seconds
# Processed: Image_964.jpg, elapsed time: 1.06 seconds
# Processed: Image_1157.jpg, elapsed time: 1.05 seconds
# Processed: Image_1190.jpg, elapsed time: 1.05 seconds
# Processed: Image_1229.jpg, elapsed time: 1.03 seconds
# Processed: Image_1290.jpg, elapsed time: 1.05 seconds
# Processed: Image_134.jpg, elapsed time: 1.04 seconds
# Processed: Image_137.jpg, elapsed time: 1.00 seconds
# Processed: Image_1375.jpg, elapsed time: 1.01 seconds
# Processed: Image_1408.jpg, elapsed time: 1.00 seconds
# Processed: Image_1482.jpg, elapsed time: 0.99 seconds
# Processed: Image_1574.jpg, elapsed time: 1.01 seconds
# Processed: Image_1575.jpg, elapsed time: 1.00 seconds
# Processed: Image_1591.jpg, elapsed time: 1.07 seconds
# Processed: Image_160.jpg, elapsed time: 1.04 seconds
# Processed: Image_1867.jpg, elapsed time: 1.10 seconds
# Processed: Image_1970.jpg, elapsed time: 1.08 seconds
# Processed: Image_1995.jpg, elapsed time: 1.02 seconds
# Processed: Image_2060.jpg, elapsed time: 1.05 seconds
# Processed: Image_2092.jpg, elapsed time: 1.02 seconds
# Processed: Image_2099.jpg, elapsed time: 1.01 seconds
# Processed: Image_2201.jpg, elapsed time: 1.06 seconds
# Processed: Image_2213.jpg, elapsed time: 1.05 seconds
# Processed: Image_2311.jpg, elapsed time: 1.04 seconds
# Processed: Image_2341.jpg, elapsed time: 1.06 seconds
# Processed: Image_2414.jpg, elapsed time: 1.06 seconds
# Processed: Image_25.jpg, elapsed time: 1.05 seconds
# Processed: Image_2561.jpg, elapsed time: 1.04 seconds
# Processed: Image_261.jpg, elapsed time: 1.03 seconds
# Processed: Image_2695.jpg, elapsed time: 1.05 seconds
# Processed: Image_29.jpg, elapsed time: 1.08 seconds
# Processed: Image_2935.jpg, elapsed time: 1.02 seconds
# Processed: Image_2946.jpg, elapsed time: 1.15 seconds
# Processed: Image_2965.jpg, elapsed time: 1.06 seconds
# Processed: Image_2972.jpg, elapsed time: 1.02 seconds
# Processed: Image_3014.jpg, elapsed time: 1.03 seconds
# Processed: Image_3082.jpg, elapsed time: 1.02 seconds
# Processed: Image_3157.jpg, elapsed time: 1.05 seconds
# Processed: Image_3266.jpg, elapsed time: 1.04 seconds
# Processed: Image_3317.jpg, elapsed time: 1.02 seconds
# Processed: Image_3347.jpg, elapsed time: 1.03 seconds
# Processed: Image_3469.jpg, elapsed time: 1.03 seconds
# Processed: Image_3548.jpg, elapsed time: 1.03 seconds
# Processed: Image_3613.jpg, elapsed time: 0.99 seconds
# Processed: Image_3739.jpg, elapsed time: 1.00 seconds
# Processed: Image_377.jpg, elapsed time: 1.00 seconds
# Processed: Image_3888.jpg, elapsed time: 1.00 seconds
# Processed: Image_3924.jpg, elapsed time: 1.01 seconds
# Processed: Image_3961.jpg, elapsed time: 0.98 seconds
# Processed: Image_4067.jpg, elapsed time: 1.00 seconds
# Processed: Image_4343.jpg, elapsed time: 0.98 seconds
# Processed: Image_4346.jpg, elapsed time: 1.00 seconds
# Processed: Image_4353.jpg, elapsed time: 0.99 seconds
# Processed: Image_4426.jpg, elapsed time: 0.99 seconds
# Processed: Image_4468.jpg, elapsed time: 1.04 seconds
# Processed: Image_4517.jpg, elapsed time: 1.03 seconds
# Processed: Image_4595.jpg, elapsed time: 1.03 seconds
# Processed: Image_4645.jpg, elapsed time: 1.05 seconds
# Processed: Image_4673.jpg, elapsed time: 1.06 seconds
# Processed: Image_4767.jpg, elapsed time: 1.00 seconds
# Processed: Image_4831.jpg, elapsed time: 1.02 seconds
# Processed: Image_4891.jpg, elapsed time: 0.99 seconds
# Processed: Image_5020.jpg, elapsed time: 0.98 seconds
# Processed: Image_5118.jpg, elapsed time: 0.99 seconds
# Processed: Image_5134.jpg, elapsed time: 0.99 seconds
# Processed: Image_5151.jpg, elapsed time: 0.98 seconds
# Processed: Image_5200.jpg, elapsed time: 0.99 seconds
# Processed: Image_5253.jpg, elapsed time: 0.99 seconds
# Processed: Image_5407.jpg, elapsed time: 1.02 seconds
# Processed: Image_5415.jpg, elapsed time: 0.99 seconds
# Processed: Image_5417.jpg, elapsed time: 1.00 seconds
# Processed: Image_5438.jpg, elapsed time: 0.99 seconds
# Processed: Image_5457.jpg, elapsed time: 0.99 seconds
# Processed: Image_5475.jpg, elapsed time: 0.98 seconds
# Processed: Image_5533.jpg, elapsed time: 0.99 seconds
# Processed: Image_5614.jpg, elapsed time: 1.00 seconds
# Processed: Image_5620.jpg, elapsed time: 1.00 seconds
# Processed: Image_5648.jpg, elapsed time: 1.00 seconds
# Processed: Image_5741.jpg, elapsed time: 0.99 seconds
# Processed: Image_5817.jpg, elapsed time: 1.03 seconds
# Processed: Image_5877.jpg, elapsed time: 0.99 seconds
# Processed: Image_5883.jpg, elapsed time: 1.00 seconds
# Processed: Image_5979.jpg, elapsed time: 0.99 seconds
# Processed: Image_6073.jpg, elapsed time: 0.97 seconds
# Processed: Image_6086.jpg, elapsed time: 0.98 seconds
# Processed: Image_6239.jpg, elapsed time: 1.00 seconds
# Processed: Image_6336.jpg, elapsed time: 0.98 seconds
# Processed: Image_6342.jpg, elapsed time: 1.00 seconds
# Processed: Image_6399.jpg, elapsed time: 0.99 seconds
# Processed: Image_6435.jpg, elapsed time: 1.03 seconds
# Processed: Image_6471.jpg, elapsed time: 1.00 seconds
# Processed: Image_707.jpg, elapsed time: 0.98 seconds
# Processed: Image_776.jpg, elapsed time: 1.00 seconds
# Processed: Image_94.jpg, elapsed time: 1.00 seconds
# Processed: Image_1042.jpg, elapsed time: 1.00 seconds
# Processed: Image_1062.jpg, elapsed time: 0.98 seconds
# Processed: Image_1222.jpg, elapsed time: 0.98 seconds
# Processed: Image_1322.jpg, elapsed time: 1.00 seconds
# Processed: Image_1331.jpg, elapsed time: 1.01 seconds
# Processed: Image_1354.jpg, elapsed time: 1.03 seconds
# Processed: Image_1421.jpg, elapsed time: 0.99 seconds
# Processed: Image_1448.jpg, elapsed time: 0.98 seconds
# Processed: Image_1508.jpg, elapsed time: 0.99 seconds
# Processed: Image_1567.jpg, elapsed time: 1.01 seconds
# Processed: Image_1573.jpg, elapsed time: 0.99 seconds
# Processed: Image_1713.jpg, elapsed time: 1.00 seconds
# Processed: Image_1751.jpg, elapsed time: 1.00 seconds
# Processed: Image_1764.jpg, elapsed time: 1.00 seconds
# Processed: Image_1771.jpg, elapsed time: 1.01 seconds
# Processed: Image_1815.jpg, elapsed time: 1.03 seconds
# Processed: Image_1914.jpg, elapsed time: 0.99 seconds
# Processed: Image_1969.jpg, elapsed time: 0.99 seconds
# Processed: Image_198.jpg, elapsed time: 0.99 seconds
# Processed: Image_1998.jpg, elapsed time: 1.00 seconds
# Processed: Image_2129.jpg, elapsed time: 0.99 seconds
# Processed: Image_2266.jpg, elapsed time: 0.98 seconds
# Processed: Image_2299.jpg, elapsed time: 1.01 seconds
# Processed: Image_2440.jpg, elapsed time: 0.99 seconds
# Processed: Image_2496.jpg, elapsed time: 1.00 seconds
# Processed: Image_2535.jpg, elapsed time: 1.00 seconds
# Processed: Image_2570.jpg, elapsed time: 1.02 seconds
# Processed: Image_2599.jpg, elapsed time: 1.01 seconds
# Processed: Image_2605.jpg, elapsed time: 0.99 seconds
# Processed: Image_2622.jpg, elapsed time: 1.00 seconds
# Processed: Image_2673.jpg, elapsed time: 0.98 seconds
# Processed: Image_2725.jpg, elapsed time: 0.99 seconds
# Processed: Image_2738.jpg, elapsed time: 0.99 seconds
# Processed: Image_2744.jpg, elapsed time: 0.99 seconds
# Processed: Image_276.jpg, elapsed time: 1.01 seconds
# Processed: Image_2776.jpg, elapsed time: 0.99 seconds
# Processed: Image_2834.jpg, elapsed time: 1.03 seconds
# Processed: Image_2912.jpg, elapsed time: 1.00 seconds
# Processed: Image_2914.jpg, elapsed time: 0.99 seconds
# Processed: Image_3003.jpg, elapsed time: 0.99 seconds
# Processed: Image_3139.jpg, elapsed time: 0.99 seconds
# Processed: Image_3168.jpg, elapsed time: 1.00 seconds
# Processed: Image_3238.jpg, elapsed time: 0.99 seconds
# Processed: Image_3256.jpg, elapsed time: 0.99 seconds
# Processed: Image_3420.jpg, elapsed time: 0.99 seconds
# Processed: Image_3435.jpg, elapsed time: 0.99 seconds
# Processed: Image_3584.jpg, elapsed time: 1.00 seconds
# Processed: Image_3707.jpg, elapsed time: 0.99 seconds
# Processed: Image_3785.jpg, elapsed time: 1.00 seconds
# Processed: Image_3793.jpg, elapsed time: 0.98 seconds
# Processed: Image_3797.jpg, elapsed time: 1.01 seconds
# Processed: Image_3848.jpg, elapsed time: 0.99 seconds
# Processed: Image_3903.jpg, elapsed time: 0.98 seconds
# Processed: Image_3935.jpg, elapsed time: 1.02 seconds
# Processed: Image_3994.jpg, elapsed time: 0.99 seconds
# Processed: Image_4084.jpg, elapsed time: 0.98 seconds
# Processed: Image_4111.jpg, elapsed time: 0.99 seconds
# Processed: Image_4299.jpg, elapsed time: 1.03 seconds
# Processed: Image_4327.jpg, elapsed time: 0.99 seconds
# Processed: Image_4388.jpg, elapsed time: 0.99 seconds
# Processed: Image_4513.jpg, elapsed time: 0.99 seconds
# Processed: Image_4573.jpg, elapsed time: 0.99 seconds
# Processed: Image_4612.jpg, elapsed time: 0.99 seconds
# Processed: Image_4683.jpg, elapsed time: 1.00 seconds
# Processed: Image_4777.jpg, elapsed time: 0.99 seconds
# Processed: Image_4905.jpg, elapsed time: 0.99 seconds
# Processed: Image_4995.jpg, elapsed time: 0.99 seconds
# Processed: Image_5001.jpg, elapsed time: 1.03 seconds
# Processed: Image_5137.jpg, elapsed time: 1.00 seconds
# Processed: Image_5255.jpg, elapsed time: 0.98 seconds
# Processed: Image_53.jpg, elapsed time: 0.99 seconds
# Processed: Image_5331.jpg, elapsed time: 0.98 seconds
# Processed: Image_5371.jpg, elapsed time: 0.98 seconds
# Processed: Image_5464.jpg, elapsed time: 0.98 seconds
# Processed: Image_5530.jpg, elapsed time: 1.00 seconds
# Processed: Image_5565.jpg, elapsed time: 1.00 seconds
# Processed: Image_5616.jpg, elapsed time: 1.03 seconds
# Processed: Image_5623.jpg, elapsed time: 0.98 seconds
# Processed: Image_5705.jpg, elapsed time: 1.02 seconds
# Processed: Image_5768.jpg, elapsed time: 0.99 seconds
# Processed: Image_5779.jpg, elapsed time: 1.01 seconds
# Processed: Image_5889.jpg, elapsed time: 0.97 seconds
# Processed: Image_5899.jpg, elapsed time: 0.99 seconds
# Processed: Image_59.jpg, elapsed time: 0.98 seconds
# Processed: Image_619.jpg, elapsed time: 0.99 seconds
# Processed: Image_6240.jpg, elapsed time: 0.99 seconds
# Processed: Image_6245.jpg, elapsed time: 0.98 seconds
# Processed: Image_6303.jpg, elapsed time: 1.00 seconds
# Processed: Image_6328.jpg, elapsed time: 1.01 seconds
# Processed: Image_636.jpg, elapsed time: 0.98 seconds
# Processed: Image_6362.jpg, elapsed time: 0.98 seconds
# Processed: Image_6443.jpg, elapsed time: 0.98 seconds
# Processed: Image_802.jpg, elapsed time: 1.00 seconds
# Processed: Image_875.jpg, elapsed time: 1.00 seconds
# Processed: Image_878.jpg, elapsed time: 1.00 seconds
# Processed: Image_918.jpg, elapsed time: 0.97 seconds
# Processed: Image_97.jpg, elapsed time: 1.00 seconds

# %%
def extract_color_moments(image):
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    means = np.mean(image_rgb, axis=(0, 1)) 
    stds = np.std(image_rgb, axis=(0, 1))  
    skews = skew(image_rgb.reshape((-1, 3)), axis=0)  

    features = np.concatenate([means, stds, skews])
    columns = [
        'means_R', 'means_G', 'means_B',
        'std_R', 'std_G', 'std_B',
        'skew_R', 'skew_G', 'skew_B'
    ]
    
    return features, columns

def extract_features_from_folder(root_dir):
    data = []
    columns = []
    labels = []

    for class_name in os.listdir(root_dir):
        class_path = os.path.join(root_dir, class_name)
        if not os.path.isdir(class_path):
            continue
        
        print(f"Processing class: {class_name}")
        for img_file in os.listdir(class_path):
            img_path = os.path.join(class_path, img_file)
            image = cv2.imread(img_path)
            if image is None:
                continue
            features, columns = extract_color_moments(image)
            data.append(features)
            labels.append(class_name)

    df = pd.DataFrame(data, columns=columns)
    df['label'] = labels
    return df

df = extract_features_from_folder(output_path)
df.to_csv("data/color_moments_features.csv", index=False)
print("Feature extraction complete. Saved to color_moments_features.csv")
# Out:
# Processing class: adonis
# Processing class: clouded_sulphur
# Processing class: scarce_swallow
# Feature extraction complete. Saved to color_moments_features.csv
